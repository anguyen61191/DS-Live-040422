# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"21309135886","type":"PushEvent","actor":{"id":74385,"login":"rstacruz","display_login":"rstacruz","gravatar_id":"","url":"https://api.github.com/users/rstacruz","avatar_url":"https://avatars.githubusercontent.com/u/74385?"},"repo":{"id":481636098,"name":"rstacruz/marp-basetype","url":"https://api.github.com/repos/rstacruz/marp-basetype"},"payload":{"push_id":9636668683,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"d3e03a70775c2a54174a219786d55e0f3fa707e0","before":"88e85eadae8cf37a117002b8bc7830b466c3107e","commits":[{"sha":"d3e03a70775c2a54174a219786d55e0f3fa707e0","author":{"email":"rstacruz@users.noreply.github.com","name":"Rico Sta. Cruz"},"message":"Initial implementation of vertical layout","distinct":true,"url":"https://api.github.com/repos/rstacruz/marp-basetype/commits/d3e03a70775c2a54174a219786d55e0f3fa707e0"}]},"public":true,"created_at":"2022-04-15T16:06:35Z"},{"id":"21309135906","type":"PushEvent","actor":{"id":24492986,"login":"Kashif875","display_login":"Kashif875","gravatar_id":"","url":"https://api.github.com/users/Kashif875","avatar_url":"https://avatars.githubusercontent.com/u/24492986?"},"repo":{"id":477457040,"name":"Kashif875/react_elmo_admin","url":"https://api.github.com/repos/Kashif875/react_elmo_admin"},"payload":{"push_id":9636668685,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"81ee23906365ee55fe76e217a474844013917778","before":"2dad5e3fe7dad1c5a5f049d99554045fd5ff8d80","commits":[{"sha":"81ee23906365ee55fe76e217a474844013917778","author":{"email":"kashif@globeshout.com","name":"KashifHussainH"},"message":"Bug Fixes","distinct":true,"url":"https://api.github.com/repos/Kashif875/react_elmo_admin/commits/81ee23906365ee55fe76e217a474844013917778"}]},"public":true,"created_at":"2022-04-15T16:06:35Z"},{"id":"21309135893","type":"PushEvent","actor":{"id":103764074,"login":"xiangminisverynice","display_login":"xiangminisverynice","gravatar_id":"","url":"https://api.github.com/users/xiangminisverynice","avatar_url":"https://avatars.githubusercontent.com/u/103764074?"},"repo":{"id":482010499,"name":"xiangminisverynice/51-Mlx90614-","url":"https://api.github.com/repos/xiangminisverynice/51-Mlx90614-"},"payload":{"push_id":9636668682,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ca00b2134a61419633c9318ec2a13432e312e288","before":"67f1368e49a57c0b6580f2f73ebfe642f0237f78","commits":[{"sha":"ca00b2134a61419633c9318ec2a13432e312e288","author":{"email":"103764074+xiangminisverynice@users.noreply.github.com","name":"xiangminisverynice"},"message":"Create README.md","distinct":true,"url":"https://api.github.com/repos/xiangminisverynice/51-Mlx90614-/commits/ca00b2134a61419633c9318ec2a13432e312e288"}]},"public":true,"created_at":"2022-04-15T16:06:35Z"},{"id":"21309135890","type":"PushEvent","actor":{"id":102544818,"login":"Dev-Jabwa","display_login":"Dev-Jabwa","gravatar_id":"","url":"https://api.github.com/users/Dev-Jabwa","avatar_url":"https://avatars.githubusercontent.com/u/102544818?"},"repo":{"id":481981303,"name":"Dev-Jabwa/JABWA","url":"https://api.github.com/repos/Dev-Jabwa/JABWA"},"payload":{"push_id":9636668676,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"0b0dc39656b07e05523f156c2800b7d5638819f1","before":"c8ad4ddadd49d236f01405b7eb50dde25f30106e","commits":[{"sha":"0b0dc39656b07e05523f156c2800b7d5638819f1","author":{"email":"102544818+Dev-Jabwa@users.noreply.github.com","name":"Dev-Jabwa"},"message":"Add files via upload","distinct":true,"url":"https://api.github.com/repos/Dev-Jabwa/JABWA/commits/0b0dc39656b07e05523f156c2800b7d5638819f1"}]},"public":true,"created_at":"2022-04-15T16:06:35Z"},{"id":"21309135884","type":"CreateEvent","actor":{"id":2967915,"login":"hellfur","display_login":"hellfur","gravatar_id":"","url":"https://api.github.com/users/hellfur","avatar_url":"https://avatars.githubusercontent.com/u/2967915?"},"repo":{"id":482012843,"name":"hellfur/BananTwitchRedirect","url":"https://api.github.com/repos/hellfur/BananTwitchRedirect"},"p ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Fri, 15 Apr 2022 16:11:35 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"7f97a3feaea84eb85906f13959ba623a636aca031c268407fad04bcf5944c4b9"', 'Last-Modified': 'Fri, 15 Apr 2022 16:06:35 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '57', 'X-RateLimit-Reset': '1650039826', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '3', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'D72E:43FC:19342EF:479E1D1:62599937'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '21309135886',
#   'type': 'PushEvent',
#   'actor': {'id': 74385,
#    'login': 'rstacruz',
#    'display_login': 'rstacruz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rstacruz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74385?'},
#   'repo': {'id': 481636098,
#    'name': 'rstacruz/marp-basetype',
#    'url': 'https://api.github.com/repos/rstacruz/marp-basetype'},
#   'payload': {'push_id': 9636668683,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd3e03a70775c2a54174a219786d55e0f3fa707e0',
#    'before': '88e85eadae8cf37a117002b8bc7830b466c3107e',
#    'commits': [{'sha': 'd3e03a70775c2a54174a219786d55e0f3fa707e0',
#      'author': {'email': 'rstacruz@users.noreply.github.com',
#       'name': 'Rico Sta. Cruz'},
#      'message': 'Initial implementation of vertical layout',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rstacruz/marp-basetype/commits/d3e03a70775c2a54174a219786d55e0f3fa707e0'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135906',
#   'type': 'PushEvent',
#   'actor': {'id': 24492986,
#    'login': 'Kashif875',
#    'display_login': 'Kashif875',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kashif875',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24492986?'},
#   'repo': {'id': 477457040,
#    'name': 'Kashif875/react_elmo_admin',
#    'url': 'https://api.github.com/repos/Kashif875/react_elmo_admin'},
#   'payload': {'push_id': 9636668685,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '81ee23906365ee55fe76e217a474844013917778',
#    'before': '2dad5e3fe7dad1c5a5f049d99554045fd5ff8d80',
#    'commits': [{'sha': '81ee23906365ee55fe76e217a474844013917778',
#      'author': {'email': 'kashif@globeshout.com', 'name': 'KashifHussainH'},
#      'message': 'Bug Fixes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Kashif875/react_elmo_admin/commits/81ee23906365ee55fe76e217a474844013917778'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135893',
#   'type': 'PushEvent',
#   'actor': {'id': 103764074,
#    'login': 'xiangminisverynice',
#    'display_login': 'xiangminisverynice',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiangminisverynice',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103764074?'},
#   'repo': {'id': 482010499,
#    'name': 'xiangminisverynice/51-Mlx90614-',
#    'url': 'https://api.github.com/repos/xiangminisverynice/51-Mlx90614-'},
#   'payload': {'push_id': 9636668682,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ca00b2134a61419633c9318ec2a13432e312e288',
#    'before': '67f1368e49a57c0b6580f2f73ebfe642f0237f78',
#    'commits': [{'sha': 'ca00b2134a61419633c9318ec2a13432e312e288',
#      'author': {'email': '103764074+xiangminisverynice@users.noreply.github.com',
#       'name': 'xiangminisverynice'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xiangminisverynice/51-Mlx90614-/commits/ca00b2134a61419633c9318ec2a13432e312e288'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135890',
#   'type': 'PushEvent',
#   'actor': {'id': 102544818,
#    'login': 'Dev-Jabwa',
#    'display_login': 'Dev-Jabwa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dev-Jabwa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102544818?'},
#   'repo': {'id': 481981303,
#    'name': 'Dev-Jabwa/JABWA',
#    'url': 'https://api.github.com/repos/Dev-Jabwa/JABWA'},
#   'payload': {'push_id': 9636668676,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0b0dc39656b07e05523f156c2800b7d5638819f1',
#    'before': 'c8ad4ddadd49d236f01405b7eb50dde25f30106e',
#    'commits': [{'sha': '0b0dc39656b07e05523f156c2800b7d5638819f1',
#      'author': {'email': '102544818+Dev-Jabwa@users.noreply.github.com',
#       'name': 'Dev-Jabwa'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Dev-Jabwa/JABWA/commits/0b0dc39656b07e05523f156c2800b7d5638819f1'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135884',
#   'type': 'CreateEvent',
#   'actor': {'id': 2967915,
#    'login': 'hellfur',
#    'display_login': 'hellfur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hellfur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2967915?'},
#   'repo': {'id': 482012843,
#    'name': 'hellfur/BananTwitchRedirect',
#    'url': 'https://api.github.com/repos/hellfur/BananTwitchRedirect'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135901',
#   'type': 'CreateEvent',
#   'actor': {'id': 30055306,
#    'login': 'murytarlah',
#    'display_login': 'murytarlah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/murytarlah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30055306?'},
#   'repo': {'id': 482012408,
#    'name': 'murytarlah/brickbreaker',
#    'url': 'https://api.github.com/repos/murytarlah/brickbreaker'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'A brickbreaker game made with pure js',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135900',
#   'type': 'CreateEvent',
#   'actor': {'id': 8223396,
#    'login': 'MadWolfDynamite',
#    'display_login': 'MadWolfDynamite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MadWolfDynamite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8223396?'},
#   'repo': {'id': 363955945,
#    'name': 'MadWolfDynamite/madwolf-twitchbot',
#    'url': 'https://api.github.com/repos/MadWolfDynamite/madwolf-twitchbot'},
#   'payload': {'ref': 'db-implementation',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'WPF Client that uses TwitchLib to create a bot that manages various commands',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135881',
#   'type': 'PushEvent',
#   'actor': {'id': 20414083,
#    'login': 'JayKay24',
#    'display_login': 'JayKay24',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JayKay24',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20414083?'},
#   'repo': {'id': 480097863,
#    'name': 'JayKay24/ElloAssignment',
#    'url': 'https://api.github.com/repos/JayKay24/ElloAssignment'},
#   'payload': {'push_id': 9636668668,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'aa68186152852777eb4144d07eb15cbb6c4a4d22',
#    'before': '171e167d3df48ec181b7b16f1bd3cbfbb9531930',
#    'commits': [{'sha': 'aa68186152852777eb4144d07eb15cbb6c4a4d22',
#      'author': {'email': 'jameskinyua590@gmail.com', 'name': 'Jimmy'},
#      'message': 'Remove e2e tests from workflow file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JayKay24/ElloAssignment/commits/aa68186152852777eb4144d07eb15cbb6c4a4d22'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135862',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 435437972,
#    'name': 'v2hot/v2hot.github.io',
#    'url': 'https://api.github.com/repos/v2hot/v2hot.github.io'},
#   'payload': {'push_id': 9636668652,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '10e5aaa30c6878ac6ef7d45753b75839e2a9e154',
#    'before': '1a5d6df1e200fa961aa5b8939ef5823df8ae33f1',
#    'commits': [{'sha': '10e5aaa30c6878ac6ef7d45753b75839e2a9e154',
#      'author': {'email': 'pipecraft.net@gmail.com', 'name': 'PipecraftNet'},
#      'message': 'Deploying to gh-pages from @ v2hot/v2hot.github.io@a3ded2a157ff1fbd9acd28f4c6ca657a5413f783 🚀',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/v2hot/v2hot.github.io/commits/10e5aaa30c6878ac6ef7d45753b75839e2a9e154'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z',
#   'org': {'id': 95616611,
#    'login': 'v2hot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/v2hot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95616611?'}},
#  {'id': '21309135868',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 244694174,
#    'name': 'project-chip/connectedhomeip',
#    'url': 'https://api.github.com/repos/project-chip/connectedhomeip'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333',
#     'repository_url': 'https://api.github.com/repos/project-chip/connectedhomeip',
#     'labels_url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333/comments',
#     'events_url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333/events',
#     'html_url': 'https://github.com/project-chip/connectedhomeip/pull/17333',
#     'id': 1203416851,
#     'node_id': 'PR_kwDODpW8ns42LsCb',
#     'number': 17333,
#     'title': "[Darwin] Crash when resolving node's IPs if it's discovered on more t…",
#     'user': {'login': 'vivien-apple',
#      'id': 65897387,
#      'node_id': 'MDQ6VXNlcjY1ODk3Mzg3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/65897387?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vivien-apple',
#      'html_url': 'https://github.com/vivien-apple',
#      'followers_url': 'https://api.github.com/users/vivien-apple/followers',
#      'following_url': 'https://api.github.com/users/vivien-apple/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vivien-apple/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vivien-apple/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vivien-apple/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vivien-apple/orgs',
#      'repos_url': 'https://api.github.com/users/vivien-apple/repos',
#      'events_url': 'https://api.github.com/users/vivien-apple/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vivien-apple/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2223860052,
#       'node_id': 'MDU6TGFiZWwyMjIzODYwMDUy',
#       'url': 'https://api.github.com/repos/project-chip/connectedhomeip/labels/platform',
#       'name': 'platform',
#       'color': 'dd56b9',
#       'default': False,
#       'description': ''},
#      {'id': 2223860098,
#       'node_id': 'MDU6TGFiZWwyMjIzODYwMDk4',
#       'url': 'https://api.github.com/repos/project-chip/connectedhomeip/labels/darwin',
#       'name': 'darwin',
#       'color': '13ad9d',
#       'default': False,
#       'description': ''},
#      {'id': 3008756373,
#       'node_id': 'MDU6TGFiZWwzMDA4NzU2Mzcz',
#       'url': 'https://api.github.com/repos/project-chip/connectedhomeip/labels/review%20-%20pending',
#       'name': 'review - pending',
#       'color': 'FBCA04',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'vivien-apple',
#      'id': 65897387,
#      'node_id': 'MDQ6VXNlcjY1ODk3Mzg3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/65897387?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vivien-apple',
#      'html_url': 'https://github.com/vivien-apple',
#      'followers_url': 'https://api.github.com/users/vivien-apple/followers',
#      'following_url': 'https://api.github.com/users/vivien-apple/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vivien-apple/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vivien-apple/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vivien-apple/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vivien-apple/orgs',
#      'repos_url': 'https://api.github.com/users/vivien-apple/repos',
#      'events_url': 'https://api.github.com/users/vivien-apple/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vivien-apple/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'vivien-apple',
#       'id': 65897387,
#       'node_id': 'MDQ6VXNlcjY1ODk3Mzg3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/65897387?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/vivien-apple',
#       'html_url': 'https://github.com/vivien-apple',
#       'followers_url': 'https://api.github.com/users/vivien-apple/followers',
#       'following_url': 'https://api.github.com/users/vivien-apple/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/vivien-apple/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/vivien-apple/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/vivien-apple/subscriptions',
#       'organizations_url': 'https://api.github.com/users/vivien-apple/orgs',
#       'repos_url': 'https://api.github.com/users/vivien-apple/repos',
#       'events_url': 'https://api.github.com/users/vivien-apple/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/vivien-apple/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2022-04-13T14:53:28Z',
#     'updated_at': '2022-04-15T16:06:35Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/project-chip/connectedhomeip/pulls/17333',
#      'html_url': 'https://github.com/project-chip/connectedhomeip/pull/17333',
#      'diff_url': 'https://github.com/project-chip/connectedhomeip/pull/17333.diff',
#      'patch_url': 'https://github.com/project-chip/connectedhomeip/pull/17333.patch',
#      'merged_at': None},
#     'body': '…han one interface\r\n\r\n#### Problem\r\n\r\nSince https://github.com/project-chip/connectedhomeip/pull/17246 Darwin is crashing if there are multiple interfaces broadcasting over mdns when resolving the ip.\r\n\r\nfix #17288\r\n\r\n#### Change overview\r\n * share the connection so `kDNSServiceFlagsMoreComing` is shared across the possible various calls of `DNSServiceGetAddrInfo`.\r\n\r\n#### Testing\r\n`chip-tool` does not crash anymore.\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/comments/1100200388',
#     'html_url': 'https://github.com/project-chip/connectedhomeip/pull/17333#issuecomment-1100200388',
#     'issue_url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/17333',
#     'id': 1100200388,
#     'node_id': 'IC_kwDODpW8ns5Bk7nE',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-04-15T16:06:34Z',
#     'updated_at': '2022-04-15T16:06:34Z',
#     'author_association': 'NONE',
#     'body': 'PR #17333: Size comparison from 0680f217ac7313e5df56ae90946e45206515729e to fe8dae1e6f9d6fa40e57bfd5c8977056f6a51a31\n<!--ghr-comment-format:1-->\n\n<details>\n<summary>Full report (5 builds for cyw30739, nrfconnect, telink)</summary>\n<!--ghr-report:full-->\n\n| platform   | target                            | config              | section       |   0680f217 |   fe8dae1e |   change |   % change |\n|:-----------|:----------------------------------|:--------------------|:--------------|-----------:|-----------:|---------:|-----------:|\n| cyw30739   | light                             | cyw930739m2evb_01   | (read/write)  |     619134 |     619134 |        0 |        0.0 |\n|            |                                   |                     | .app_xip_area |     525892 |     525892 |        0 |        0.0 |\n|            |                                   |                     | .bss          |      75908 |      75908 |        0 |        0.0 |\n|            |                                   |                     | .data         |        684 |        684 |        0 |        0.0 |\n|            |                                   |                     | .rodata       |          0 |          0 |        0 |        0.0 |\n|            |                                   |                     | .text         |          0 |          0 |        0 |        0.0 |\n|            | lock                              | cyw930739m2evb_01   | (read/write)  |     613394 |     613394 |        0 |        0.0 |\n|            |                                   |                     | .app_xip_area |     521656 |     521656 |        0 |        0.0 |\n|            |                                   |                     | .bss          |      74436 |      74436 |        0 |        0.0 |\n|            |                                   |                     | .data         |        648 |        648 |        0 |        0.0 |\n|            |                                   |                     | .rodata       |          0 |          0 |        0 |        0.0 |\n|            |                                   |                     | .text         |          0 |          0 |        0 |        0.0 |\n|            | ota-requestor-no-progress-logging | cyw930739m2evb_01   | (read/write)  |     565838 |     565838 |        0 |        0.0 |\n|            |                                   |                     | .app_xip_area |     464504 |     464504 |        0 |        0.0 |\n|            |                                   |                     | .bss          |      83736 |      83736 |        0 |        0.0 |\n|            |                                   |                     | .data         |        564 |        564 |        0 |        0.0 |\n|            |                                   |                     | .rodata       |          0 |          0 |        0 |        0.0 |\n|            |                                   |                     | .text         |        112 |        112 |        0 |        0.0 |\n| nrfconnect | all-clusters-app                  | nrf52840dk_nrf52840 | (read/write)  |    1163883 |    1163883 |        0 |        0.0 |\n|            |                                   |                     | bss           |     136492 |     136492 |        0 |        0.0 |\n|            |                                   |                     | rodata        |     147276 |     147276 |        0 |        0.0 |\n|            |                                   |                     | text          |     801444 |     801444 |        0 |        0.0 |\n| telink     | lighting-app                      | tlsr9518adk80d      | (read/write)  |     801664 |     801664 |        0 |        0.0 |\n|            |                                   |                     | bss           |      69952 |      69952 |        0 |        0.0 |\n|            |                                   |                     | noinit       ...
#     'reactions': {'url': 'https://api.github.com/repos/project-chip/connectedhomeip/issues/comments/1100200388/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z',
#   'org': {'id': 61027988,
#    'login': 'project-chip',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/project-chip',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61027988?'}},
#  {'id': '21309135852',
#   'type': 'PushEvent',
#   'actor': {'id': 59910950,
#    'login': 'ss-o',
#    'display_login': 'ss-o',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ss-o',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59910950?'},
#   'repo': {'id': 442984856,
#    'name': 'z-shell/zw',
#    'url': 'https://api.github.com/repos/z-shell/zw'},
#   'payload': {'push_id': 9636668650,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0d1b854270cdfdfdcf3c14c890a87336f98959be',
#    'before': '5a94c164cde5ee87e757450faa2281c2a7bf233a',
#    'commits': [{'sha': '0d1b854270cdfdfdcf3c14c890a87336f98959be',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump crowdin/github-action from 1.4.7 to 1.4.8 (#377)\n\nBumps [crowdin/github-action](https://github.com/crowdin/github-action) from 1.4.7 to 1.4.8.\r\n- [Release notes](https://github.com/crowdin/github-action/releases)\r\n- [Commits](https://github.com/crowdin/github-action/compare/1.4.7...1.4.8)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: crowdin/github-action\r\n  dependency-type: direct:production\r\n  update-type: version-update:semver-patch\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\n\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/z-shell/zw/commits/0d1b854270cdfdfdcf3c14c890a87336f98959be'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z',
#   'org': {'id': 93575852,
#    'login': 'z-shell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/z-shell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93575852?'}},
#  {'id': '21309135851',
#   'type': 'PushEvent',
#   'actor': {'id': 9131757,
#    'login': 'thcolin',
#    'display_login': 'thcolin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thcolin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9131757?'},
#   'repo': {'id': 239215499,
#    'name': 'thcolin/galerie-gaia',
#    'url': 'https://api.github.com/repos/thcolin/galerie-gaia'},
#   'payload': {'push_id': 9636668664,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '6a35345cbc2ec84425f8c8fe8b0cb659db2ccb0c',
#    'before': '0f617ed7361950edd4225e021ffaf62537a79546',
#    'commits': [{'sha': '6a35345cbc2ec84425f8c8fe8b0cb659db2ccb0c',
#      'author': {'email': 'thcolin@users.noreply.github.com',
#       'name': 'thcolin'},
#      'message': 'deployed via Gatsby Publish Action 🎩 for e55e040a8d8ac2d68fa3305fce190ca4a22eb4de',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thcolin/galerie-gaia/commits/6a35345cbc2ec84425f8c8fe8b0cb659db2ccb0c'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135864',
#   'type': 'CreateEvent',
#   'actor': {'id': 68789173,
#    'login': 'wivien19',
#    'display_login': 'wivien19',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wivien19',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68789173?'},
#   'repo': {'id': 482012841,
#    'name': 'wivien19/c_sharp',
#    'url': 'https://api.github.com/repos/wivien19/c_sharp'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135848',
#   'type': 'CreateEvent',
#   'actor': {'id': 43916339,
#    'login': 'kfung15',
#    'display_login': 'kfung15',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kfung15',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43916339?'},
#   'repo': {'id': 482012842,
#    'name': 'kfung15/digital-ocean-app',
#    'url': 'https://api.github.com/repos/kfung15/digital-ocean-app'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135825',
#   'type': 'PushEvent',
#   'actor': {'id': 67561520,
#    'login': 'Loomeh',
#    'display_login': 'Loomeh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Loomeh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67561520?'},
#   'repo': {'id': 482012072,
#    'name': 'Loomeh/jsrwebsite',
#    'url': 'https://api.github.com/repos/Loomeh/jsrwebsite'},
#   'payload': {'push_id': 9636668647,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '21f14fd2e524cd12a5c14091ad827a8663914217',
#    'before': 'dce41f2497a2fc41f6212d12c02707c749833a2d',
#    'commits': [{'sha': '21f14fd2e524cd12a5c14091ad827a8663914217',
#      'author': {'email': '67561520+Loomeh@users.noreply.github.com',
#       'name': 'Loomeh'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Loomeh/jsrwebsite/commits/21f14fd2e524cd12a5c14091ad827a8663914217'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135839',
#   'type': 'PushEvent',
#   'actor': {'id': 38898948,
#    'login': 'DreyIMM',
#    'display_login': 'DreyIMM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DreyIMM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38898948?'},
#   'repo': {'id': 469525012,
#    'name': 'DreyIMM/Notes',
#    'url': 'https://api.github.com/repos/DreyIMM/Notes'},
#   'payload': {'push_id': 9636668631,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd30f49031b8ac885a638679e775e300eee1800d2',
#    'before': '42b0140f2dccbf13f1cc35151bea0fdbd5aa7e2d',
#    'commits': [{'sha': 'd30f49031b8ac885a638679e775e300eee1800d2',
#      'author': {'email': 'andreydario26@gmail.com', 'name': 'DreyIMM'},
#      'message': 'Criando uma nova nota',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DreyIMM/Notes/commits/d30f49031b8ac885a638679e775e300eee1800d2'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135832',
#   'type': 'PushEvent',
#   'actor': {'id': 46196147,
#    'login': 'Sharindog',
#    'display_login': 'Sharindog',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sharindog',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46196147?'},
#   'repo': {'id': 480919069,
#    'name': 'Sharindog/settings',
#    'url': 'https://api.github.com/repos/Sharindog/settings'},
#   'payload': {'push_id': 9636668635,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/main',
#    'head': '208635b0146f2b0f3fbb1ff8d41651bb9eb55422',
#    'before': '29697aa86c6ca53e184826f8bff2d9e68860ac7f',
#    'commits': [{'sha': '93d3efe15b71f5eb446175f9cb5e940856320c80',
#      'author': {'email': '33565251+ega22a@users.noreply.github.com',
#       'name': 'Egor Repiev'},
#      'message': 'Merge pull request #1 from Sharindog/main\n\nInkScape Installation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sharindog/settings/commits/93d3efe15b71f5eb446175f9cb5e940856320c80'},
#     {'sha': 'ccfac45b1a3a501675107523e3fe396b3b8966d1',
#      'author': {'email': '33565251+ega22a@users.noreply.github.com',
#       'name': 'Egor Repiev'},
#      'message': 'ИСПРАВИЛ БАГ',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sharindog/settings/commits/ccfac45b1a3a501675107523e3fe396b3b8966d1'},
#     {'sha': '2d528859f7111107a9cf281afd0bcab67ddcbc3e',
#      'author': {'email': '33565251+ega22a@users.noreply.github.com',
#       'name': 'Egor Repiev'},
#      'message': 'Откат.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sharindog/settings/commits/2d528859f7111107a9cf281afd0bcab67ddcbc3e'},
#     {'sha': '53e0108f0b4defc88071b8ceaf8b4cf78e660698',
#      'author': {'email': '33565251+ega22a@users.noreply.github.com',
#       'name': 'Egor Repiev'},
#      'message': 'ФИКС',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sharindog/settings/commits/53e0108f0b4defc88071b8ceaf8b4cf78e660698'},
#     {'sha': '208635b0146f2b0f3fbb1ff8d41651bb9eb55422',
#      'author': {'email': 'sharindog@ya.ru', 'name': 'Sharindog'},
#      'message': "Merge remote-tracking branch 'upstream/main'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sharindog/settings/commits/208635b0146f2b0f3fbb1ff8d41651bb9eb55422'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135815',
#   'type': 'PushEvent',
#   'actor': {'id': 63002614,
#    'login': 'Beta-cheater',
#    'display_login': 'Beta-cheater',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Beta-cheater',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63002614?'},
#   'repo': {'id': 471698408,
#    'name': 'Beta-cheater/itde',
#    'url': 'https://api.github.com/repos/Beta-cheater/itde'},
#   'payload': {'push_id': 9636668634,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'acf080c4ea28a917120549d552ee52467d68f90a',
#    'before': '4b319ca7629012aa50fd0adea6f64672088c9bdf',
#    'commits': [{'sha': 'acf080c4ea28a917120549d552ee52467d68f90a',
#      'author': {'email': '63002614+Beta-cheater@users.noreply.github.com',
#       'name': 'Beater (beta-cheater)'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Beta-cheater/itde/commits/acf080c4ea28a917120549d552ee52467d68f90a'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135826',
#   'type': 'PushEvent',
#   'actor': {'id': 68384104,
#    'login': 'mayrang',
#    'display_login': 'mayrang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mayrang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68384104?'},
#   'repo': {'id': 480618475,
#    'name': 'mayrang/CloneUnionClubHomePage',
#    'url': 'https://api.github.com/repos/mayrang/CloneUnionClubHomePage'},
#   'payload': {'push_id': 9636668636,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f9a6125cdf81784c9345a282cf9013da0bb0e529',
#    'before': 'cc56db677cc89eb7569c5adcc3643a9fcd71e7fa',
#    'commits': [{'sha': 'f9a6125cdf81784c9345a282cf9013da0bb0e529',
#      'author': {'email': 'pkss0626@naver.com', 'name': 'mayrang'},
#      'message': 'make_SlideBorder_componant',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mayrang/CloneUnionClubHomePage/commits/f9a6125cdf81784c9345a282cf9013da0bb0e529'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135842',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 5885521,
#    'login': 'wilsonianb',
#    'display_login': 'wilsonianb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wilsonianb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5885521?'},
#   'repo': {'id': 208362384,
#    'name': 'interledger/open-payments',
#    'url': 'https://api.github.com/repos/interledger/open-payments'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/interledger/open-payments/pulls/comments/851352567',
#     'pull_request_review_id': 943526399,
#     'id': 851352567,
#     'node_id': 'PRRC_kwDODGtbkM4yvpv3',
#     'diff_hunk': "@@ -823,15 +1013,8 @@ components:\n           $ref: '#/components/schemas/amount'\n         sendAmount:\n           $ref: '#/components/schemas/amount'\n-        fundsAvailable:\n-          type: boolean\n-          description: Indicates that there are funds available in the underlying account to complete this payment. This is not a guarantee they will still be available when the payment is attempted but it is a good indicator to a client that it should attempt to authorize the payment.\n-          readOnly: true\n-        expiresAt:\n-          type: string\n-          description: The date and time when the calculated `sendAmount` is no longer valid.\n-          example: '2022-04-12T23:20:50.52Z'\n-          readOnly: true",
#     'path': 'open-api-spec.yaml',
#     'position': 560,
#     'original_position': 560,
#     'commit_id': '9a91081daf5250e49075a4e226e2afdd2b7611f8',
#     'original_commit_id': '9a91081daf5250e49075a4e226e2afdd2b7611f8',
#     'user': {'login': 'wilsonianb',
#      'id': 5885521,
#      'node_id': 'MDQ6VXNlcjU4ODU1MjE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5885521?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wilsonianb',
#      'html_url': 'https://github.com/wilsonianb',
#      'followers_url': 'https://api.github.com/users/wilsonianb/followers',
#      'following_url': 'https://api.github.com/users/wilsonianb/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wilsonianb/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wilsonianb/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wilsonianb/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wilsonianb/orgs',
#      'repos_url': 'https://api.github.com/users/wilsonianb/repos',
#      'events_url': 'https://api.github.com/users/wilsonianb/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wilsonianb/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Otherwise, I'm considering implementing separate quoted and un-quoted outgoing payments database tables (maybe one [inheriting](https://www.postgresql.org/docs/current/ddl-inherit.html) from the other).",
#     'created_at': '2022-04-15T16:06:34Z',
#     'updated_at': '2022-04-15T16:06:34Z',
#     'html_url': 'https://github.com/interledger/open-payments/pull/97#discussion_r851352567',
#     'pull_request_url': 'https://api.github.com/repos/interledger/open-payments/pulls/97',
#     'author_association': 'NONE',
#     '_links': {'self': {'href': 'https://api.github.com/repos/interledger/open-payments/pulls/comments/851352567'},
#      'html': {'href': 'https://github.com/interledger/open-payments/pull/97#discussion_r851352567'},
#      'pull_request': {'href': 'https://api.github.com/repos/interledger/open-payments/pulls/97'}},
#     'reactions': {'url': 'https://api.github.com/repos/interledger/open-payments/pulls/comments/851352567/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 834,
#     'original_line': 834,
#     'side': 'LEFT',
#     'in_reply_to_id': 850753133},
#    'pull_request': {'url': 'https://api.github.com/repos/interledger/open-payments/pulls/97',
#     'id': 900844224,
#     'node_id': 'PR_kwDODGtbkM41scrA',
#     'html_url': 'https://github.com/interledger/open-payments/pull/97',
#     'diff_url': 'https://github.com/interledger/open-payments/pull/97.diff',
#     'patch_url': 'https://github.com/interledger/open-payments/pull/97.patch',
#     'issue_url': 'https://api.github.com/repos/interledger/open-payments/issues/97',
#     'number': 97,
#     'state': 'open',
#     'locked': False,
#     'title': 'feat: add quotes',
#     'user': {'login': 'wilsonianb',
#      'id': 5885521,
#      'node_id': 'MDQ6VXNlcjU4ODU1MjE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5885521?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wilsonianb',
#      'html_url': 'https://github.com/wilsonianb',
#      'followers_url': 'https://api.github.com/users/wilsonianb/followers',
#      'following_url': 'https://api.github.com/users/wilsonianb/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wilsonianb/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wilsonianb/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wilsonianb/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wilsonianb/orgs',
#      'repos_url': 'https://api.github.com/users/wilsonianb/repos',
#      'events_url': 'https://api.github.com/users/wilsonianb/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wilsonianb/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Remove Outgoing Payment authorization and update.',
#     'created_at': '2022-04-06T00:12:18Z',
#     'updated_at': '2022-04-15T16:06:34Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'a25da2482078a338d5b64bbaa14df8b851020ed0',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'adrianhopebailie',
#       'id': 49902,
#       'node_id': 'MDQ6VXNlcjQ5OTAy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49902?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/adrianhopebailie',
#       'html_url': 'https://github.com/adrianhopebailie',
#       'followers_url': 'https://api.github.com/users/adrianhopebailie/followers',
#       'following_url': 'https://api.github.com/users/adrianhopebailie/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/adrianhopebailie/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/adrianhopebailie/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/adrianhopebailie/subscriptions',
#       'organizations_url': 'https://api.github.com/users/adrianhopebailie/orgs',
#       'repos_url': 'https://api.github.com/users/adrianhopebailie/repos',
#       'events_url': 'https://api.github.com/users/adrianhopebailie/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/adrianhopebailie/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'sabineschaller',
#       'id': 16089022,
#       'node_id': 'MDQ6VXNlcjE2MDg5MDIy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/16089022?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sabineschaller',
#       'html_url': 'https://github.com/sabineschaller',
#       'followers_url': 'https://api.github.com/users/sabineschaller/followers',
#       'following_url': 'https://api.github.com/users/sabineschaller/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sabineschaller/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sabineschaller/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sabineschaller/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sabineschaller/orgs',
#       'repos_url': 'https://api.github.com/users/sabineschaller/repos',
#       'events_url': 'https://api.github.com/users/sabineschaller/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sabineschaller/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'njlie',
#       'id': 20246798,
#       'node_id': 'MDQ6VXNlcjIwMjQ2Nzk4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/20246798?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/njlie',
#       'html_url': 'https://github.com/njlie',
#       'followers_url': 'https://api.github.com/users/njlie/followers',
#       'following_url': 'https://api.github.com/users/njlie/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/njlie/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/njlie/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/njlie/subscriptions',
#       'organizations_url': 'https://api.github.com/users/njlie/orgs',
#       'repos_url': 'https://api.github.com/users/njlie/repos',
#       'events_url': 'https://api.github.com/users/njlie/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/njlie/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/interledger/open-payments/pulls/97/commits',
#     'review_comments_url': 'https://api.github.com/repos/interledger/open-payments/pulls/97/comments',
#     'review_comment_url': 'https://api.github.com/repos/interledger/open-payments/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/interledger/open-payments/issues/97/comments',
#     'statuses_url': 'https://api.github.com/repos/interledger/open-payments/statuses/9a91081daf5250e49075a4e226e2afdd2b7611f8',
#     'head': {'label': 'wilsonianb:bw-quotes',
#      'ref': 'bw-quotes',
#      'sha': '9a91081daf5250e49075a4e226e2afdd2b7611f8',
#      'user': {'login': 'wilsonianb',
#       'id': 5885521,
#       'node_id': 'MDQ6VXNlcjU4ODU1MjE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5885521?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wilsonianb',
#       'html_url': 'https://github.com/wilsonianb',
#       'followers_url': 'https://api.github.com/users/wilsonianb/followers',
#       'following_url': 'https://api.github.com/users/wilsonianb/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wilsonianb/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wilsonianb/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wilsonianb/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wilsonianb/orgs',
#       'repos_url': 'https://api.github.com/users/wilsonianb/repos',
#       'events_url': 'https://api.github.com/users/wilsonianb/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wilsonianb/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 225969836,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU5Njk4MzY=',
#       'name': 'open-payments',
#       'full_name': 'wilsonianb/open-payments',
#       'private': False,
#       'owner': {'login': 'wilsonianb',
#        'id': 5885521,
#        'node_id': 'MDQ6VXNlcjU4ODU1MjE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5885521?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wilsonianb',
#        'html_url': 'https://github.com/wilsonianb',
#        'followers_url': 'https://api.github.com/users/wilsonianb/followers',
#        'following_url': 'https://api.github.com/users/wilsonianb/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wilsonianb/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wilsonianb/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wilsonianb/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wilsonianb/orgs',
#        'repos_url': 'https://api.github.com/users/wilsonianb/repos',
#        'events_url': 'https://api.github.com/users/wilsonianb/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wilsonianb/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/wilsonianb/open-payments',
#       'description': 'Protocol to setup payments between entities on the Web based on OAuth 2.0',
#       'fork': True,
#       'url': 'https://api.github.com/repos/wilsonianb/open-payments',
#       'forks_url': 'https://api.github.com/repos/wilsonianb/open-payments/forks',
#       'keys_url': 'https://api.github.com/repos/wilsonianb/open-payments/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wilsonianb/open-payments/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wilsonianb/open-payments/teams',
#       'hooks_url': 'https://api.github.com/repos/wilsonianb/open-payments/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wilsonianb/open-payments/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wilsonianb/open-payments/events',
#       'assignees_url': 'https://api.github.com/repos/wilsonianb/open-payments/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wilsonianb/open-payments/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wilsonianb/open-payments/tags',
#       'blobs_url': 'https://api.github.com/repos/wilsonianb/open-payments/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wilsonianb/open-payments/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wilsonianb/open-payments/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wilsonianb/open-payments/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wilsonianb/open-payments/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wilsonianb/open-payments/languages',
#       'stargazers_url': 'https://api.github.com/repos/wilsonianb/open-payments/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wilsonianb/open-payments/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wilsonianb/open-payments/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wilsonianb/open-payments/subscription',
#       'commits_url': 'https://api.github.com/repos/wilsonianb/open-payments/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wilsonianb/open-payments/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wilsonianb/open-payments/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wilsonianb/open-payments/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wilsonianb/open-payments/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wilsonianb/open-payments/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wilsonianb/open-payments/merges',
#       'archive_url': 'https://api.github.com/repos/wilsonianb/open-payments/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wilsonianb/open-payments/downloads',
#       'issues_url': 'https://api.github.com/repos/wilsonianb/open-payments/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wilsonianb/open-payments/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wilsonianb/open-payments/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wilsonianb/open-payments/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wilsonianb/open-payments/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wilsonianb/open-payments/releases{/id}',
# ...
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/interledger',
#        'html_url': 'https://github.com/interledger',
#        'followers_url': 'https://api.github.com/users/interledger/followers',
#        'following_url': 'https://api.github.com/users/interledger/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/interledger/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/interledger/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/interledger/subscriptions',
#        'organizations_url': 'https://api.github.com/users/interledger/orgs',
#        'repos_url': 'https://api.github.com/users/interledger/repos',
#        'events_url': 'https://api.github.com/users/interledger/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/interledger/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/interledger/open-payments',
#       'description': 'Protocol to setup payments between entities on the Web based on OAuth 2.0',
#       'fork': False,
#       'url': 'https://api.github.com/repos/interledger/open-payments',
#       'forks_url': 'https://api.github.com/repos/interledger/open-payments/forks',
#       'keys_url': 'https://api.github.com/repos/interledger/open-payments/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/interledger/open-payments/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/interledger/open-payments/teams',
#       'hooks_url': 'https://api.github.com/repos/interledger/open-payments/hooks',
#       'issue_events_url': 'https://api.github.com/repos/interledger/open-payments/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/interledger/open-payments/events',
#       'assignees_url': 'https://api.github.com/repos/interledger/open-payments/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/interledger/open-payments/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/interledger/open-payments/tags',
#       'blobs_url': 'https://api.github.com/repos/interledger/open-payments/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/interledger/open-payments/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/interledger/open-payments/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/interledger/open-payments/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/interledger/open-payments/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/interledger/open-payments/languages',
#       'stargazers_url': 'https://api.github.com/repos/interledger/open-payments/stargazers',
#       'contributors_url': 'https://api.github.com/repos/interledger/open-payments/contributors',
#       'subscribers_url': 'https://api.github.com/repos/interledger/open-payments/subscribers',
#       'subscription_url': 'https://api.github.com/repos/interledger/open-payments/subscription',
#       'commits_url': 'https://api.github.com/repos/interledger/open-payments/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/interledger/open-payments/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/interledger/open-payments/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/interledger/open-payments/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/interledger/open-payments/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/interledger/open-payments/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/interledger/open-payments/merges',
#       'archive_url': 'https://api.github.com/repos/interledger/open-payments/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/interledger/open-payments/downloads',
#       'issues_url': 'https://api.github.com/repos/interledger/open-payments/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/interledger/open-payments/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/interledger/open-payments/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/interledger/open-payments/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/interledger/open-payments/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/interledger/open-payments/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/interledger/open-payments/deployments',
#       'created_at': '2019-09-13T23:29:08Z',
#       'updated_at': '2022-04-13T15:14:26Z',
#       'pushed_at': '2022-04-13T14:40:32Z',
#       'git_url': 'git://github.com/interledger/open-payments.git',
#       'ssh_url': 'git@github.com:interledger/open-payments.git',
#       'clone_url': 'https://github.com/interledger/open-payments.git',
#       'svn_url': 'https://github.com/interledger/open-payments',
#       'homepage': 'https://openpayments.dev',
#       'size': 7371,
#       'stargazers_count': 70,
#       'watchers_count': 70,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 18,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 47,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 18,
#       'open_issues': 47,
#       'watchers': 70,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/interledger/open-payments/pulls/97'},
#      'html': {'href': 'https://github.com/interledger/open-payments/pull/97'},
#      'issue': {'href': 'https://api.github.com/repos/interledger/open-payments/issues/97'},
#      'comments': {'href': 'https://api.github.com/repos/interledger/open-payments/issues/97/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/interledger/open-payments/pulls/97/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/interledger/open-payments/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/interledger/open-payments/pulls/97/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/interledger/open-payments/statuses/9a91081daf5250e49075a4e226e2afdd2b7611f8'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z',
#   'org': {'id': 14062960,
#    'login': 'interledger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/interledger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14062960?'}},
#  {'id': '21309135828',
#   'type': 'PushEvent',
#   'actor': {'id': 49400064,
#    'login': 'byronoc123',
#    'display_login': 'byronoc123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/byronoc123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49400064?'},
#   'repo': {'id': 482011361,
#    'name': 'byronoc123/lambda-api-cdk',
#    'url': 'https://api.github.com/repos/byronoc123/lambda-api-cdk'},
#   'payload': {'push_id': 9636668640,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '06f5de2f31682a7a3053f2ba2f40fa85daa85c9b',
#    'before': '539f8c2a3005041bbd9fc643490c7f94d224273e',
#    'commits': [{'sha': '06f5de2f31682a7a3053f2ba2f40fa85daa85c9b',
#      'author': {'email': 'byronoc123@gmail.com', 'name': "Byron O'Connor"},
#      'message': 'See readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/byronoc123/lambda-api-cdk/commits/06f5de2f31682a7a3053f2ba2f40fa85daa85c9b'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135800',
#   'type': 'PushEvent',
#   'actor': {'id': 45398785,
#    'login': 'SpBills',
#    'display_login': 'SpBills',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SpBills',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45398785?'},
#   'repo': {'id': 395354079,
#    'name': 'CreativeSolutionsGroup/bz-commendations-api',
#    'url': 'https://api.github.com/repos/CreativeSolutionsGroup/bz-commendations-api'},
#   'payload': {'push_id': 9636668624,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd1f35327c856db363d36f99ef3476778143a5bdf',
#    'before': '1bef269b58ffdb68146d7aa8a821aa54b4d08b5e',
#    'commits': [{'sha': 'd1f35327c856db363d36f99ef3476778143a5bdf',
#      'author': {'email': 'spencebills0@gmail.com', 'name': 'spbills'},
#      'message': 'Peer dep',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CreativeSolutionsGroup/bz-commendations-api/commits/d1f35327c856db363d36f99ef3476778143a5bdf'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z',
#   'org': {'id': 74683069,
#    'login': 'CreativeSolutionsGroup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CreativeSolutionsGroup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74683069?'}},
#  {'id': '21309135814',
#   'type': 'DeleteEvent',
#   'actor': {'id': 102581199,
#    'login': 'Ponifty',
#    'display_login': 'Ponifty',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ponifty',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102581199?'},
#   'repo': {'id': 482008213,
#    'name': 'Ponifty/hello-world',
#    'url': 'https://api.github.com/repos/Ponifty/hello-world'},
#   'payload': {'ref': 'readme-edits',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135784',
#   'type': 'WatchEvent',
#   'actor': {'id': 24302531,
#    'login': 'davidjrea',
#    'display_login': 'davidjrea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davidjrea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24302531?'},
#   'repo': {'id': 443398914,
#    'name': 'INFORMSJoC/2021.0171',
#    'url': 'https://api.github.com/repos/INFORMSJoC/2021.0171'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z',
#   'org': {'id': 69215098,
#    'login': 'INFORMSJoC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/INFORMSJoC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69215098?'}},
#  {'id': '21309135775',
#   'type': 'PushEvent',
#   'actor': {'id': 4176826,
#    'login': 'MarcoEidinger',
#    'display_login': 'MarcoEidinger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoEidinger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4176826?'},
#   'repo': {'id': 482008604,
#    'name': 'TeamEidinger/cloud-sdk-ios',
#    'url': 'https://api.github.com/repos/TeamEidinger/cloud-sdk-ios'},
#   'payload': {'push_id': 9636668619,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c99c5193c0cfe9a32fd4ede4ae77f736b3157531',
#    'before': 'c9dad34fce31b81f2ea8c090c5cecc50c18153bc',
#    'commits': [{'sha': 'c99c5193c0cfe9a32fd4ede4ae77f736b3157531',
#      'author': {'email': 'marco.eidinger@sap.com', 'name': 'Marco Eidinger'},
#      'message': 'Create ci.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TeamEidinger/cloud-sdk-ios/commits/c99c5193c0cfe9a32fd4ede4ae77f736b3157531'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:34Z',
#   'org': {'id': 63104676,
#    'login': 'TeamEidinger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/TeamEidinger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63104676?'}},
#  {'id': '21309135792',
#   'type': 'PushEvent',
#   'actor': {'id': 67924910,
#    'login': 'zoometh',
#    'display_login': 'zoometh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zoometh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67924910?'},
#   'repo': {'id': 281720933,
#    'name': 'zoometh/Rdev',
#    'url': 'https://api.github.com/repos/zoometh/Rdev'},
#   'payload': {'push_id': 9636668615,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '358aeb9cf86c169d5b90b5ec76c0228e5a63faa9',
#    'before': 'b567b278a729dd1e934159b8ad0e56f4c9eadd59',
#    'commits': [{'sha': '358aeb9cf86c169d5b90b5ec76c0228e5a63faa9',
#      'author': {'email': 'thomashuet7@gmail.com', 'name': 'zoometh'},
#      'message': 'bckgrd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zoometh/Rdev/commits/358aeb9cf86c169d5b90b5ec76c0228e5a63faa9'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135783',
#   'type': 'PushEvent',
#   'actor': {'id': 26388471,
#    'login': 'ManaswineeB',
#    'display_login': 'ManaswineeB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ManaswineeB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26388471?'},
#   'repo': {'id': 465098368,
#    'name': 'ManaswineeB/TAMIDSBeanQueens',
#    'url': 'https://api.github.com/repos/ManaswineeB/TAMIDSBeanQueens'},
#   'payload': {'push_id': 9636668627,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c50c59599b1851ad0386c80e3d9d9bf11ef25104',
#    'before': 'b61ad2694b9dbb96e33d34bbabfc208e3c54e0ac',
#    'commits': [{'sha': 'c50c59599b1851ad0386c80e3d9d9bf11ef25104',
#      'author': {'email': 'bezba004@umn.edu', 'name': 'ManaswineeB'},
#      'message': 'taco',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ManaswineeB/TAMIDSBeanQueens/commits/c50c59599b1851ad0386c80e3d9d9bf11ef25104'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:35Z'},
#  {'id': '21309135772',
#   'type': 'PushEvent',
#   'actor': {'id': 41921528,
#    'login': 'Cainier',
#    'display_login': 'Cainier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Cainier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41921528?'},
#   'repo': {'id': 333341673,
#    'name': 'openSFTP/opensftp',
#    'url': 'https://api.github.com/repos/openSFTP/opensftp'},
#   'payload': {'push_id': 9636668594,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature-v4.1',
#    'head': '84d49ee3d2471e28c5e5f3aa94c4268562aebb4e',
#    'before': '02f2a219014ea2ed7eee5fefdb4520fcc4c08bb1',
#    'commits': [{'sha': '84d49ee3d2471e28c5e5f3aa94c4268562aebb4e',
#      'author': {'email': 'xingrong.dev@gmail.com', 'name': 'Cainier'},
#      'message': 'dev',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/openSFTP/opensftp/commits/84d49ee3d2471e28c5e5f3aa94c4268562aebb4e'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:34Z',
#   'org': {'id': 82311478,
#    'login': 'openSFTP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openSFTP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82311478?'}},
#  {'id': '21309135773',
#   'type': 'PushEvent',
#   'actor': {'id': 11916033,
#    'login': 'mtl1979',
#    'display_login': 'mtl1979',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mtl1979',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11916033?'},
#   'repo': {'id': 34763258,
#    'name': 'mtl1979/zlib-ng',
#    'url': 'https://api.github.com/repos/mtl1979/zlib-ng'},
#   'payload': {'push_id': 9636668591,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/notests',
#    'head': 'afcd9ad38dfeba4db4ec4397875755c73a1dc4d3',
#    'before': '723d5a836071c66e4abf5fb41f75ea27ff6c7136',
#    'commits': [{'sha': 'afcd9ad38dfeba4db4ec4397875755c73a1dc4d3',
#      'author': {'email': 'postmaster@raasu.org', 'name': 'Mika Lindqvist'},
#      'message': "Don't try to build tests or benchmarks if cmake is too old for them.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mtl1979/zlib-ng/commits/afcd9ad38dfeba4db4ec4397875755c73a1dc4d3'}]},
#   'public': True,
#   'created_at': '2022-04-15T16:06:34Z'}]

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# How does that need to adapt for charmander?
char_url = f"{base_poke_url}charmander"

# %%
# Check the status code, will this work?
requests.get(char_url)
# Out:
# <Response [200]>

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['id']
# Out:
# 4

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
poke_type[ for i in char_resp["types"] if i == "name"]
# Out:
#   File "<ipython-input-17-04146157a237>", line 1
#     poke_type[ for i in char_resp["types"] if i == "name"]
#                ^
# SyntaxError: invalid syntax

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
#     poke_list[]
#     for key, value in poke_resp.items():
#         if key == "id":
#             poke_list.append(value)
#         elif key == "name":
#             poke_list.append(value)
    poke_id = poke_resp["id"]
    poke_name = poke_resp["name"]
    poke_type_list = []
    for i in poke_resp["types"]:
        poke_type_list.append(i['type']['name'])
        
    
#     primary_type =  poke_resp["types"]["type"]["name"][0]
#     if len(poke_resp['types']) = 1:
#         secondary_type =  poke_resp['types']['type']["name"][1]
#     else :
#         secondary_type = None
        
    return[poke_id,poke_name, *poke_type_list]
    pass

# %%
get_pokemon_details(char_resp)

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10,3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire']
# [7, 'squirtle', 'water']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
col_names
# Out:
# ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(1)
# And then loop over our pokemon ids!

    
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
# poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     try:
# --> 564         columns = _validate_or_indexify_columns(content, columns)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     687             # caller's responsibility to check for this...
# --> 688             raise AssertionError(
#     689                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 4 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-731be361cc3b> in <module>
#      14 # Then, concat everything into one df
#      15 # Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
# ---> 16 poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)
#
# <ipython-input-28-731be361cc3b> in <listcomp>(.0)
#      14 # Then, concat everything into one df
#      15 # Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
# ---> 16 poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                     if is_named_tuple(data[0]) and columns is None:
#     508                         columns = data[0]._fields
# --> 509                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     510                     columns = ensure_index(columns)
#     511
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     522         return [], []  # columns if columns is not None else []
#     523     if isinstance(data[0], (list, tuple)):
# --> 524         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     525     elif isinstance(data[0], abc.Mapping):
#     526         return _list_of_dict_to_arrays(
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     566     except AssertionError as e:
# --> 567         raise ValueError(e) from e
#     568     return result, columns
#     569
#
# ValueError: 4 columns passed, passed data had 3 columns

# %%
for row in row_list:
    if len(row) == 3:
        row.append(None)

# %%
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           None
# 4      5  charmeleon         fire           None
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           None
# 147  148   dragonair       dragon           None
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           None
# 150  151         mew      psychic           None
#
# [151 rows x 4 columns]

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!
#
# https://www.themoviedb.org/documentation/api

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# You can make a secrets folder on your ~ directory!
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Quick helper function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/anguy/.secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from key import tmdb_key

tmdb_key_2 = tmdb_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
test_resp = requests.get(test_url).json()

# %%
test_resp.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
# Find similar movies to the previous id
fight_club_id = 550
similar_url = f"https://api.themoviedb.org/3/movie/{fight_club_id}/similar?api_key={tmdb_key_1}"
similar_resp = requests.get(similar_url).json()

# %%
similar_resp.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
# How many similar movies did it find?
similar_resp['total_results']
# Out:
# 10000

# %%
# but is that the length of these results?
len(similar_resp['results'])
# Out:
# 20

# %%
# what's in here?
for res in similar_resp['results']:
    print(res['title'])
# Out:
# Cry Macho
# American Badger
# The Colony
# Black Crab
# Outlaws
# Don't Kill Me
# Battle: Freestyle
# I, Robot
# Barry Lyndon
# Night Watch
# Doctor Dolittle
# The Treasure of the Sierra Madre
# Girl, Interrupted
# Emma
# The Number 23
# The Machinist
# The Story of O
# Sense and Sensibility
# Flash Gordon
# Girl with a Pearl Earring

# %% [markdown]
# ## Level Up: Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit: Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
